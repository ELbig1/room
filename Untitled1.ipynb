# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
import matplotlib.pyplot as plt
import warnings
import joblib
from imblearn.over_sampling import SMOTE

warnings.filterwarnings("ignore")

# %%
# Load the dataset
df = pd.read_csv("/content/Crop_Recommendation.csv")
df
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# ...

# %%
# Data Preprocessing
df2 = df.drop(columns=['Crop'])
numeric_columns = ['Nitrogen'	,'Phosphorus',	'Potassium'	,'Temperature'	,'Humidity'	,'pH_Value'	,'Rainfall']
scaler = MinMaxScaler()
df2[numeric_columns] = scaler.fit_transform(df2[numeric_columns])
df2
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature  Humidity  pH_Value  \
# 0     0.642857    0.264286      0.190     0.345886  0.790267  0.466264
# 1     0.607143    0.378571      0.180     0.371445  0.770633  0.549480
# 2     0.428571    0.357143      0.195     0.406854  0.793977  0.674219
# 3     0.528571    0.214286      0.175     0.506901  0.768751  0.540508
# 4     0.557143    0.264286      0.185     0.324378  0.785626  0.641291
# ...        ...         ...        ...          ...       ...       ...
# 2195  0.764286    0.207143      0.135     0.515037  0.608410  0.509353
# 2196  0.707143    0.071429      0.110     0.533473  0.494359  0.401561
# 2197  0.842857    0.200000      0.125     0.439202  0.617880  0.444433
# 2198  0.835714    0.192857      0.145     0.500627  0.441760  0.506045
# 2199  0.742857    0.092857      0.125     0.424029  0.538222  0.509317
#
#       Rainfall
# 0     0.656458
# 1     0.741675
# 2     0.875710
# 3     0.799905
# 4     0.871231
# ...        ...
# ...

# %%
# Features and target
x = df2
y = df['Crop']

# %%
# Label Encoding for the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.1, random_state=42)

# %%
# Handle class imbalance using SMOTE
smote = SMOTE(random_state=11)
x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
# Model Training with GridSearchCV for hyperparameter tuning
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
grid_search = GridSearchCV(RandomForestRegressor(random_state=11), param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(x_train_smote, y_train_smote)
best_model = grid_search.best_estimator_

# %%
# Cross-validation to check the performance
kf = KFold(n_splits=5, shuffle=True, random_state=11)
cv_scores = cross_val_score(best_model, x_train_smote, y_train_smote, cv=kf, scoring='neg_mean_squared_error')
print(f"Mean CV Score: {-np.mean(cv_scores)}")
# Out:
# Mean CV Score: 1.094156678318936

# %%
# Model evaluation on the training data
train_score = best_model.score(x_train_smote, y_train_smote)
print(f"Training Score (R2): {train_score}")
# Out:
# Training Score (R2): 0.9962755799454169

# %%
# Predictions on the test data
y_pred = best_model.predict(x_test)

# %%
# Model evaluation on the test data
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print(f"Test MSE: {mse}")
print(f"Test R2: {r2}")
print(f"Test MAE: {mae}")
# Out:
# Test MSE: 0.9400136363636363
# Test R2: 0.9774483206439845
# Test MAE: 0.3004545454545455

# %%
# Plot Predicted vs Actual Data
plt.scatter(y_pred, y_test, color='blue', label='Data Points')
plt.plot([min(y_pred), max(y_pred)], [min(y_test), max(y_test)], color='red', linestyle='--', label='Perfect Predictions')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Predicted vs Actual Data')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Feature Importance
importances = best_model.feature_importances_
indices = np.argsort(importances)[::-1]
features = df2.columns
plt.figure()
plt.title("Feature Importances")
plt.bar(range(x_train.shape[1]), importances[indices], align="center")
plt.xticks(range(x_train.shape[1]), features[indices], rotation=90)
plt.show()

# %%
# Save the model
joblib.dump(best_model, 'best_random_forest_model.pkl')
# Out:
# ['best_random_forest_model.pkl']

# %%
# Mapping back the prediction to the original labels
df_y_train = pd.DataFrame(y_train)
code = pd.DataFrame(df_y_train[0].unique())
refer = pd.DataFrame()
refer['code'] = code
df_y_train_encoded = pd.DataFrame(y_train)
encode = pd.DataFrame(df_y_train_encoded[0].unique())
refer['encode'] = encode
refer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dded56373f89> in <cell line: 2>()
#       1 # Mapping back the prediction to the original labels
# ----> 2 df_y_train = pd.DataFrame(y_train)
#       3 code = pd.DataFrame(df_y_train[y_train].unique())
#       4 refer = pd.DataFrame()
#       5 refer['code'] = code
#
# NameError: name 'pd' is not defined

# %%
# Predict for a specific instance
#result_array = best_model.predict([[0.278571,	0.421429,	0.235,	0.576552,	0.937647,	0.493589,	0.156195]])
#result = result_array[0]
#predict_result = refer['code'][refer['encode'] == result]
#print(f"Predicted Crop: {predict_result.values[0]}")


# Predict for a specific instance
result_array = best_model.predict([[0.371429,	0.428571,	0.075,	0.688422,	0.605416,	0.514677,	0.174702]])
result = result_array[0]

# Print the predicted result for debugging
print(f"Predicted encoded value: {result}")

# Check if the predicted value exists in 'refer['encode']'
if result in refer['encode'].values:
    predict_result = refer['code'][refer['encode'] == result]
    print(f"Predicted Crop: {predict_result.values[0]}")
else:
    print("Predicted value not found in encoding reference.")
# Out:
# Predicted encoded value: 2.0
# Predicted Crop: 2

# %%
# Checking the label for a specific instance
print(f"Actual Crop : {df['Crop'][1556]}")
# Out:
# Actual Crop : Apple

# %%
x_test
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature  Humidity  pH_Value  \
# 1451  0.721429    0.085714      0.210     0.593069  0.938733  0.416821
# 1334  0.700000    0.021429      0.230     0.497956  0.842992  0.428373
# 1761  0.421429    0.407143      0.220     0.990962  0.922659  0.534458
# 1735  0.314286    0.392857      0.250     0.730414  0.890039  0.516399
# 1576  0.214286    0.942857      0.975     0.404267  0.891779  0.326369
# ...        ...         ...        ...          ...       ...       ...
# 56    0.528571    0.350000      0.165     0.482925  0.807385  0.562260
# 342   0.200000    0.435714      0.090     0.364829  0.116605  0.387446
# 1749  0.278571    0.421429      0.235     0.576552  0.937647  0.493589
# 2150  0.735714    0.200000      0.100     0.524434  0.484016  0.529725
# 786   0.371429    0.428571      0.075     0.688422  0.605416  0.514677
#
#       Rainfall
# 1451  0.021904
# 1334  0.104973
# 1761  0.339742
# 1735  0.281407
# 1576  0.353489
# ...        ...
# ...

# %%
print("Refer DataFrame:")
print(refer)
print("Predicted value:")
print(result)
# Out:
# Refer DataFrame:
#     code  encode
# 0      9       9
# 1     12      12
# 2      4       4
# 3     17      17
# 4      0       0
# 5      3       3
# 6     19      19
# 7     15      15
# 8      6       6
# 9     20      20
# 10     5       5
# 11    13      13
# 12    11      11
# 13    18      18
# 14    14      14
# 15     7       7
# 16     8       8
# 17     1       1
# 18     2       2
# 19    16      16
# 20    21      21
# 21    10      10
# Predicted value:
# 16.85
